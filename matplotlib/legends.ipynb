# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
x = np.linspace(0,11,10)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x,label='X vs X')
ax.plot(x,x**2)

ax.plot(x,x/2, label='X by X')
ax.legend(loc=(1.1,0.5))
