# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[40, 60, 92],
#        [64,  5, 12],
#        [93, 40, 49],
#        [83,  8, 29]])

# %%
myindex = ["CA", "NY", "AZ", "TX"]

# %%
mycolumns = ['Jan', 'Feb',"Mar"]

# %%
df = pd.DataFrame(mydata,index=myindex,columns=mycolumns)

# %%
df
# Out:
#     Jan  Feb  Mar
# CA   40   60   92
# NY   64    5   12
# AZ   93   40   49
# TX   83    8   29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
df.columns
# Out:
# Index(['Jan', 'Feb', 'Mar'], dtype='object')

# %%
df.index
# Out:
# Index(['CA', 'NY', 'AZ', 'TX'], dtype='object')

# %%
pwd
# Out:
# 'D:\\development\\personal\\datascience\\numpy\\Basic_Data_science_lib\\pandas'

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is D803-7F36
#
#  Directory of D:\development\personal\datascience\numpy\Basic_Data_science_lib\pandas
#
# 05-09-2023  01.32 PM    <DIR>          .
# 17-06-2023  04.00 PM    <DIR>          ..
# 05-09-2023  01.12 PM    <DIR>          .ipynb_checkpoints
# 05-09-2023  01.22 PM             5,690 dataframes.ipynb
# 27-07-2023  03.45 PM           179,486 practice_file.xlsx
# 05-09-2023  12.59 PM             6,991 Untitled.ipynb
#                3 File(s)        192,167 bytes
#                3 Dir(s)  305,274,834,944 bytes free

# %%
df = pd.read_excel('D:\\development\\personal\\datascience\\numpy\\Basic_Data_science_lib\\pandas\\practice_file.xlsx')

# %%
df
# Out:
#              item_sku                                              Title  \
# 0               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 1               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 2               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 3               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 4                 NaN  Superminis Kids Unisex Puppy Face Design Orang...
# ...               ...                                                ...
# 2903  50150-SMSINSRE5      Superminis Girls Rayon Printed Red Night Suit
# 2904  50150-SMSINSRE6      Superminis Girls Rayon Printed Red Night Suit
# 2905  50150-SMSINSRE7      Superminis Girls Rayon Printed Red Night Suit
# 2906  50151-SMSIKPBL0  Superminis Pure Cotton Solid Blue & White Kurt...
# 2907  50151-SMSIKPBL1  Superminis Pure Cotton Solid Blue & White Kurt...
#
#             Color1     Size1                  day   mrp Brand Category SubCat  \
# ...

# %%
 df.columns
# Out:
# Index(['item_sku', 'Title', 'Color1', 'Size1', 'day', 'mrp', 'Brand',
#        'Category', 'SubCat', 'Colour'],
#       dtype='object')

# %%
df.head()
# Out:
#   item_sku                                              Title  Color1  \
# 0    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 1    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 2    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 3    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 4      NaN  Superminis Kids Unisex Puppy Face Design Orang...  Orange
#
#       Size1                  day   mrp Brand Category SubCat  Colour
# 0    1 size  2023-01-01 00:00:00   899   ICB      MNM    KUR     RED
# 1  One Size  2023-01-01 00:00:00  1799   ICB      MNM    KUR     RED
# 2  One Size  2023-01-01 00:00:00  1799   ICB      MNM    SKD  YELLOW
# 3  One Size  2023-01-01 00:00:00    19   ICB      MNM    KUR     RED
# 4  One Size  2023-01-01 00:00:00  1799   ICB      MNM    KUR     RED

# %%
df.head(10)
# Out:
#   item_sku                                              Title  Color1  \
# 0    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 1    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 2    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 3    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 4      NaN  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 5    50157  Superminis Kids Unisex Puppy Face Design Orang...    Oran
# 6    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 7    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 8    50157  Superminis Kids Unisex Puppy Face Design Orang...  Orange
# 9    50157  Superminis Kids Unisex Puppy Face Design Orang...   Orang
#
#       Size1                  day   mrp Brand Category SubCat  Colour
# 0    1 size  2023-01-01 00:00:00   899   ICB      MNM    KUR     RED
# ...

# %%
df.tail()
# Out:
#              item_sku                                              Title  \
# 2903  50150-SMSINSRE5      Superminis Girls Rayon Printed Red Night Suit
# 2904  50150-SMSINSRE6      Superminis Girls Rayon Printed Red Night Suit
# 2905  50150-SMSINSRE7      Superminis Girls Rayon Printed Red Night Suit
# 2906  50151-SMSIKPBL0  Superminis Pure Cotton Solid Blue & White Kurt...
# 2907  50151-SMSIKPBL1  Superminis Pure Cotton Solid Blue & White Kurt...
#
#             Color1 Size1                  day  mrp Brand Category SubCat  \
# 2903           Red     5  2023-01-05 00:00:00  761   ICB      SKD    SKD
# 2904           Red     6  2023-01-05 00:00:00  420   ICB      SKD    SKD
# 2905           Red     7  2023-01-05 00:00:00  462   ICB      SKD    SKD
# 2906  Navy & White     0  2023-01-05 00:00:00  757   ICB      MNM    KUR
# 2907  Navy & White     1  2023-01-05 00:00:00  605   ICB      MNM    KUR
#
#         Colour
# 2903       BLK
# 2904       BLK
# 2905       BLK
# 2906  YEL CRBN
# ...

# %%
df.describe()
# Out:
#                mrp
# count  2908.000000
# mean   1658.671252
# std     302.936400
# min       1.000000
# 25%    1499.000000
# 50%    1799.000000
# 75%    1799.000000
# max    2499.000000

# %%
df.describe().transpose()
# Out:
#       count         mean       std  min     25%     50%     75%     max
# mrp  2908.0  1658.671252  302.9364  1.0  1499.0  1799.0  1799.0  2499.0

# %%
df['Title']
# Out:
# 0       Superminis Kids Unisex Puppy Face Design Orang...
# 1       Superminis Kids Unisex Puppy Face Design Orang...
# 2       Superminis Kids Unisex Puppy Face Design Orang...
# 3       Superminis Kids Unisex Puppy Face Design Orang...
# 4       Superminis Kids Unisex Puppy Face Design Orang...
#                               ...
# 2903        Superminis Girls Rayon Printed Red Night Suit
# 2904        Superminis Girls Rayon Printed Red Night Suit
# 2905        Superminis Girls Rayon Printed Red Night Suit
# 2906    Superminis Pure Cotton Solid Blue & White Kurt...
# 2907    Superminis Pure Cotton Solid Blue & White Kurt...
# Name: Title, Length: 2908, dtype: object

# %%
df[['Title',"Color1"]]
# Out:
#                                                   Title        Color1
# 0     Superminis Kids Unisex Puppy Face Design Orang...        Orange
# 1     Superminis Kids Unisex Puppy Face Design Orang...        Orange
# 2     Superminis Kids Unisex Puppy Face Design Orang...        Orange
# 3     Superminis Kids Unisex Puppy Face Design Orang...        Orange
# 4     Superminis Kids Unisex Puppy Face Design Orang...        Orange
# ...                                                 ...           ...
# 2903      Superminis Girls Rayon Printed Red Night Suit           Red
# 2904      Superminis Girls Rayon Printed Red Night Suit           Red
# 2905      Superminis Girls Rayon Printed Red Night Suit           Red
# 2906  Superminis Pure Cotton Solid Blue & White Kurt...  Navy & White
# 2907  Superminis Pure Cotton Solid Blue & White Kurt...  Navy & White
#
# [2908 rows x 2 columns]

# %%
df['brand_Color'] = df['Brand'] + "-" + df['Color1']

# %%
df
# Out:
#              item_sku                                              Title  \
# 0               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 1               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 2               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 3               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 4                 NaN  Superminis Kids Unisex Puppy Face Design Orang...
# ...               ...                                                ...
# 2903  50150-SMSINSRE5      Superminis Girls Rayon Printed Red Night Suit
# 2904  50150-SMSINSRE6      Superminis Girls Rayon Printed Red Night Suit
# 2905  50150-SMSINSRE7      Superminis Girls Rayon Printed Red Night Suit
# 2906  50151-SMSIKPBL0  Superminis Pure Cotton Solid Blue & White Kurt...
# 2907  50151-SMSIKPBL1  Superminis Pure Cotton Solid Blue & White Kurt...
#
#             Color1     Size1                  day   mrp Brand Category SubCat  \
# ...

# %%
df['brand_Color']
# Out:
# 0             ICB-Orange
# 1             ICB-Orange
# 2             ICB-Orange
# 3             ICB-Orange
# 4             ICB-Orange
#               ...
# 2903             ICB-Red
# 2904             ICB-Red
# 2905             ICB-Red
# 2906    ICB-Navy & White
# 2907    ICB-Navy & White
# Name: brand_Color, Length: 2908, dtype: object

# %%
np.round(df['mrp'],2)
# Out:
# 0        899
# 1       1799
# 2       1799
# 3         19
# 4       1799
#         ...
# 2903     761
# 2904     420
# 2905     462
# 2906     757
# 2907     605
# Name: mrp, Length: 2908, dtype: int64

# %%
df.drop("Color1",axis=1)
# Out:
#              item_sku                                              Title  \
# 0               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 1               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 2               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 3               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 4                 NaN  Superminis Kids Unisex Puppy Face Design Orang...
# ...               ...                                                ...
# 2903  50150-SMSINSRE5      Superminis Girls Rayon Printed Red Night Suit
# 2904  50150-SMSINSRE6      Superminis Girls Rayon Printed Red Night Suit
# 2905  50150-SMSINSRE7      Superminis Girls Rayon Printed Red Night Suit
# 2906  50151-SMSIKPBL0  Superminis Pure Cotton Solid Blue & White Kurt...
# 2907  50151-SMSIKPBL1  Superminis Pure Cotton Solid Blue & White Kurt...
#
#          Size1                  day   mrp Brand Category SubCat    Colour  \
# ...

# %%
df
# Out:
#              item_sku                                              Title  \
# 0               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 1               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 2               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 3               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 4                 NaN  Superminis Kids Unisex Puppy Face Design Orang...
# ...               ...                                                ...
# 2903  50150-SMSINSRE5      Superminis Girls Rayon Printed Red Night Suit
# 2904  50150-SMSINSRE6      Superminis Girls Rayon Printed Red Night Suit
# 2905  50150-SMSINSRE7      Superminis Girls Rayon Printed Red Night Suit
# 2906  50151-SMSIKPBL0  Superminis Pure Cotton Solid Blue & White Kurt...
# 2907  50151-SMSIKPBL1  Superminis Pure Cotton Solid Blue & White Kurt...
#
#             Color1     Size1                  day   mrp Brand Category SubCat  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2908, step=1)

# %%
df = df.set_index('Color1')

# %%
df.head()
# Out:
#        item_sku                                              Title     Size1  \
# Color1
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...    1 size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange      NaN  Superminis Kids Unisex Puppy Face Design Orang...  One Size
#
#                         day   mrp Brand Category SubCat  Colour brand_Color
# Color1
# Orange  2023-01-01 00:00:00   899   ICB      MNM    KUR     RED  ICB-Orange
# Orange  2023-01-01 00:00:00  1799   ICB      MNM    KUR     RED  ICB-Orange
# Orange  2023-01-01 00:00:00  1799   ICB      MNM    SKD  YELLOW  ICB-Orange
# Orange  2023-01-01 00:00:00    19   ICB      MNM    KUR     RED  ICB-Orange
# Orange  2023-01-01 00:00:00  1799   ICB      MNM    KUR     RED  ICB-Orange

# %%
df = df.reset_index()

# %%
df = df.set_index('Color1')

# %%
df.iloc[0]
# Out:
# item_sku                                                   50157
# Title          Superminis Kids Unisex Puppy Face Design Orang...
# Size1                                                     1 size
# day                                          2023-01-01 00:00:00
# Brand                                                        ICB
# Category                                                     MNM
# SubCat                                                       KUR
# Colour                                                       RED
# brand_Color                                           ICB-Orange
# Name: Orange, dtype: object

# %%
df.loc['Orange']
# Out:
#                  item_sku                                              Title  \
# Color1
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange                NaN  Superminis Kids Unisex Puppy Face Design Orang...
# ...                   ...                                                ...
# Orange  50146-SMSIKPEBOR7  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBOR8  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBOR9  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBORL  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBORM  Superminis Boy's Handloom Cotton Kurta with Py...
#
# ...

# %%
df.iloc[3:5]
# Out:
#        item_sku                                              Title     Size1  \
# Color1
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange      NaN  Superminis Kids Unisex Puppy Face Design Orang...  One Size
#
#                         day Brand Category SubCat Colour brand_Color
# Color1
# Orange  2023-01-01 00:00:00   ICB      MNM    KUR    RED  ICB-Orange
# Orange  2023-01-01 00:00:00   ICB      MNM    KUR    RED  ICB-Orange

# %%
df.loc[['Orange','Red']]
# Out:
#                item_sku                                              Title  \
# Color1
# Orange            50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange            50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange            50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange            50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange              NaN  Superminis Kids Unisex Puppy Face Design Orang...
# ...                 ...                                                ...
# Red     50150-SMSINSRE3      Superminis Girls Rayon Printed Red Night Suit
# Red     50150-SMSINSRE4      Superminis Girls Rayon Printed Red Night Suit
# Red     50150-SMSINSRE5      Superminis Girls Rayon Printed Red Night Suit
# Red     50150-SMSINSRE6      Superminis Girls Rayon Printed Red Night Suit
# Red     50150-SMSINSRE7      Superminis Girls Rayon Printed Red Night Suit
#
# ...

# %%
df = df.drop("Red", axis=0)

# %%
df.loc["Orange"]
# Out:
#                  item_sku                                              Title  \
# Color1
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange              50157  Superminis Kids Unisex Puppy Face Design Orang...
# Orange                NaN  Superminis Kids Unisex Puppy Face Design Orang...
# ...                   ...                                                ...
# Orange  50146-SMSIKPEBOR7  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBOR8  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBOR9  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBORL  Superminis Boy's Handloom Cotton Kurta with Py...
# Orange  50146-SMSIKPEBORM  Superminis Boy's Handloom Cotton Kurta with Py...
#
# ...

# %%
dfSelected = df.iloc[0:9]

# %%
dfSelected
# Out:
#        item_sku                                              Title     Size1  \
# Color1
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...    1 size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange      NaN  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Oran      50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...   No Size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
# Orange    50157  Superminis Kids Unisex Puppy Face Design Orang...  One Size
#
#                         day Brand Category SubCat  Colour brand_Color
# Color1
# Orange  2023-01-01 00:00:00   ICB      MNM    KUR     RED  ICB-Orange
# ...

# %%
prdf = pd.read_excel('practice_file.xlsx')

# %%
prdf = prdf.set_index('Color1')

# %%
pr_row_1 = prdf.iloc[0:1]
pr_row_2 = prdf.iloc[1:2]

# %%
df3 = pd.concat([pr_row_1, prdf], ignore_index = True)

# %%
df3
# Out:
#              item_sku                                              Title  \
# 0               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 1               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 2               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 3               50157  Superminis Kids Unisex Puppy Face Design Orang...
# 4               50157  Superminis Kids Unisex Puppy Face Design Orang...
# ...               ...                                                ...
# 2904  50150-SMSINSRE5      Superminis Girls Rayon Printed Red Night Suit
# 2905  50150-SMSINSRE6      Superminis Girls Rayon Printed Red Night Suit
# 2906  50150-SMSINSRE7      Superminis Girls Rayon Printed Red Night Suit
# 2907  50151-SMSIKPBL0  Superminis Pure Cotton Solid Blue & White Kurt...
# 2908  50151-SMSIKPBL1  Superminis Pure Cotton Solid Blue & White Kurt...
#
#          Size1                  day   mrp Brand Category SubCat    Colour
# ...
